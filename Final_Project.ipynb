# %% [markdown]
# # Final Project
#
# Now that you've been guided which experiment to run in assignment 2, you will be exploring on your own, trying to achieve the best accuracy for cifar10.
#
# In this notebook you will be asked to tune some hyperparameters, while it is recommended to tune additional hyperparameters to achieve high performance.
#
# In addition, you will be asked to read some matirials by yourselves, summeraize some of them, and combine thier innovaitive ideas in your network.
#
# You can use part of the data, in order to speed up the training, however, the **dataset size** you test on should be large. Use at least ~12000 training images and ~3000 validation images. The **batch size** parameter however is also up to you (you can increase it in order to speed up the training).
#
# You can run the experiments from several notebooks, while you save the output files in the results dictionary (choose meaningful names) and use 'plot_exp_results' to plot it.
#
# You may want to use loops in order to automatically run each section's experiments.
#
# You will will submit this notebook, all relevant the python files and a report that summerize your attempts and results. Follow the instructions and answer the question in your report.
#
# It is important to describe the hyperparameters you used, how you chose them, and how they affected your results.

# %% [markdown]
# **In each section write the best train val and test accuracy and loss.**

# %%
# !pip install tqdm==4.17.1
import os
import re
import sys
import glob
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf
import torch.nn as nn
import torch.optim as optim


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

seed = 42
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tqdm==4.17.1
#   Downloading tqdm-4.17.1-py2.py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 2.2 MB/s
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.4.2 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.17.1 which is incompatible.
# prophet 1.1.1 requires tqdm>=4.36.1, but you have tqdm 4.17.1 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.17.1 which is incompatible.
# Successfully installed tqdm-4.17.1

# %%
from google.colab import drive
drive.mount('/content/drive') 
#change this
# %cd /content/drive/MyDrive/לימודים/deep learning/final_project
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/לימודים/deep learning/final_project

# %%
from utils import *
from  utils import models
import utils.experiments as experiments
from utils.experiments import load_experiment
from utils.plot import plot_fit
import utils.training as training
torch.manual_seed(seed)

# %%
def plot_exp_results(filename_pattern, results_dir='results'):
    fig = None
    result_files = glob.glob(os.path.join(results_dir, filename_pattern))
    result_files.sort()
    if len(result_files) == 0:
        print(f'No results found for pattern {filename_pattern}.', file=sys.stderr)
        return
    for filepath in result_files:
        m = re.match('exp\d_(\d_)?(.*)\.json', os.path.basename(filepath))
        cfg, fit_res = load_experiment(filepath)
        fig, axes = plot_fit(fit_res, fig, legend=m[2],log_loss=True)
    del cfg['filters_per_layer']
    del cfg['layers_per_block']
    print('common config: ', cfg)

# %% [markdown]
# ## Build Your Own Achitecture

# %%
data_dir = os.path.expanduser('~/.pytorch-datasets')
ds_train = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=True, transform=tvtf.ToTensor())
ds_test = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=False, transform=tvtf.ToTensor())

print(f'Train: {len(ds_train)} samples')
print(f'Test: {len(ds_test)} samples')

x0,_ = ds_train[0]
in_size = x0.shape
num_classes = 10
print('input image size =', in_size)
# Out:
#   0%|          | 458752/170498071 [00:00<00:40, 4202998.56it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.pytorch-datasets/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:02<00:00, 75303103.44it/s]
# Extracting /root/.pytorch-datasets/cifar-10-python.tar.gz to /root/.pytorch-datasets
# Files already downloaded and verified
# Train: 50000 samples
# Test: 10000 samples
# input image size = torch.Size([3, 32, 32])

# %% [markdown]
# ### 1. Implement YourCodeNet model
# Implement YourCodeNet model in utiles/models and define the model architecture (use your previouse assignment's insights).
# Define `filters_per_layer`, `layers_per_block` and `hidden_dims` which you believe are the best for this task. You can run some experiments in order to set these hyperparameters.

# %% [markdown]
# To make the experiment runner use your custom network model, remember to set ycn=True when you call experiments.run_experiment(...).

# %%
# Just to see that the model run
net = models.YourCodeNet((3,100,100), 10, filters=[32]*4, pool_every=2, hidden_dims=[100]*2).to(device)
print(net)

test_image = torch.randint(low=0, high=256, size=(3, 100, 100), dtype=torch.float).to(device)
test_out = net(test_image.unsqueeze(0))
print('out =', test_out)
# Out:
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=20000, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=20000, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# out = tensor([[-0.0304, -0.5397, -0.0009,  0.0330, -0.1884,  0.0114,  0.0480,  0.0403,
#          -0.0984, -0.0154]], grad_fn=<AddmmBackward0>)

# %%
# set ycn=True when you call experiments.run_experiment(...). 
# Use meaningful names!
# ====== YOUR CODE: ======
experiments.run_experiment(f'exp_1_K32_64_128',
                                   seed=seed,
                                   bs_train=50,
                                   batches=10000,
                                   epochs=30, 
                                   early_stopping=5,
                                   reg=2e-3,
                                   lr=1e-3,
                                   filters_per_layer=[32,64,128],
                                   layers_per_block=2,
                                   pool_every=2, 
                                   ycn=True, 
                                   hidden_dims=[128])
# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU()
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.252, Accuracy 54.8): 100%|██████████| 850/850 [04:38<00:00,  3.11it/s]
# test_batch (Avg. Loss 0.932, Accuracy 66.1): 100%|██████████| 625/625 [00:21<00:00, 29.50it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 0.859, Accuracy 69.6): 100%|██████████| 850/850 [04:36<00:00,  3.10it/s]
# test_batch (Avg. Loss 0.875, Accuracy 68.6): 100%|██████████| 625/625 [00:21<00:00, 29.36it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 0.737, Accuracy 74.2): 100%|██████████| 850/850 [04:32<00:00,  3.15it/s]
# test_batch (Avg. Loss 0.688, Accuracy 76.2): 100%|██████████| 625/625 [00:20<00:00, 29.77it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 0.680, Accuracy 76.2): 100%|██████████| 850/850 [04:31<00:00,  3.11it/s]
# test_batch (Avg. Loss 0.647, Accuracy 77.8): 100%|██████████| 625/625 [00:20<00:00, 29.77it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 0.641, Accuracy 77.7): 100%|██████████| 850/850 [04:31<00:00,  3.16it/s]
# test_batch (Avg. Loss 0.646, Accuracy 77.7): 100%|██████████| 625/625 [00:20<00:00, 29.95it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.611, Accuracy 78.6): 100%|██████████| 850/850 [04:33<00:00,  3.16it/s]
# test_batch (Avg. Loss 0.624, Accuracy 78.4): 100%|██████████| 625/625 [00:20<00:00, 30.10it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.598, Accuracy 79.3): 100%|██████████| 850/850 [04:33<00:00,  3.11it/s]
# test_batch (Avg. Loss 0.596, Accuracy 79.4): 100%|██████████| 625/625 [00:20<00:00, 30.19it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0
/s]
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 0.492, Accuracy 82.9): 100%|██████████| 850/850 [09:00<00:00,  1.36it/s]
# test_batch (Avg. Loss 0.522, Accuracy 82.4): 100%|██████████| 625/625 [01:38<00:00,  6.27it/s]
# --- EPOCH 24/30 ---
# train_batch (Avg. Loss 0.497, Accuracy 82.9): 100%|██████████| 850/850 [11:29<00:00,  1.00s/it]
# test_batch (Avg. Loss 0.527, Accuracy 82.0): 100%|██████████| 625/625 [02:33<00:00,  4.10it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.498, Accuracy 82.6): 100%|██████████| 850/850 [12:50<00:00,  1.04it/s]
# test_batch (Avg. Loss 0.546, Accuracy 81.8): 100%|██████████| 625/625 [02:13<00:00,  4.63it/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 0.492, Accuracy 82.8): 100%|██████████| 850/850 [16:53<00:00,  1.34s/it]
# test_batch (Avg. Loss 0.519, Accuracy 82.2): 100%|██████████| 625/625 [03:28<00:00,  2.97it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 0.485, Accuracy 83.3): 100%|██████████| 850/850 [13:34<00:00,  1.07it/s]
# test_batch (Avg. Loss 0.535, Accuracy 82.0): 100%|██████████| 625/625 [02:16<00:00,  4.62it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 0.491, Accuracy 83.2): 100%|██████████| 850/850 [11:47<00:00,  1.41it/s]
# test_batch (Avg. Loss 0.523, Accuracy 82.1): 100%|██████████| 625/625 [01:34<00:00,  6.61it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.485, Accuracy 83.4): 100%|██████████| 850/850 [10:30<00:00,  1.28it/s]
# test_batch (Avg. Loss 0.495, Accuracy 82.6): 100%|██████████| 625/625 [01:48<00:00,  5.75it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.486, Accuracy 83.2): 100%|██████████| 850/850 [17:38<00:00,  1.52s/it]
# test_batch (Avg. Loss 0.525, Accuracy 82.5): 100%|██████████| 625/625 [04:14<00:00,  2.44it/s]
# test_batch (Avg. Loss 0.523, Accuracy 82.7): 100%|██████████| 834/834 [05:42<00:00,  3.01it/s]
# ==================== Test Results ====================
# Test Accuracy: 82.66
# Test Accuracy: 0.5233043904418496
# ======================================================
# *** Output file ./results/exp_L2_K32_64_128.json written

# %%
plot_exp_results('exp1_2_K32.json') # plot your experiments results
# Out:
# common config:  {'run_name': 'exp_L2_K32_64_128', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 2, 'hidden_dims': [128], 'ycn': True, 'kw': {}}

# %% [markdown]
# ### 2. Learning rate and optimization method
# Tune the optimization algorithm (try SGD with momentum and Adam) and the learning rate (try values between 0.0005-1, try no more than five values).

# %%
# set ycn=True when you call experiments.run_experiment(...). 
# Use meaningful names!
# ====== YOUR CODE: ======
for optim in ['sgd','adam']:
    for lr in [0.0005,0.1,0.01]:
        # Test experiment1 implementation on a few data samples and with a small model
        experiments.run_experiment(f'exp2_2_{optim}_lr{lr}',
                                   seed=seed,
                                   bs_train=64,
                                   batches=200,
                                   epochs=30, 
                                   early_stopping=5,
                                   reg=2e-3,
                                   lr=lr,
                                   filters_per_layer=[32,64,128],
                                   layers_per_block=2,
                                   pool_every=2, 
                                   ycn=True, 
                                   sgd=(optim=='sgd'),
                                   hidden_dims=[128])

# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU()
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     lr: 0.0005
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.664, Accuracy 38.5): 100%|██████████| 665/665 [00:06<00:00, 96.21it/s]
# test_batch (Avg. Loss 1.405, Accuracy 49.0): 100%|██████████| 469/469 [00:01<00:00, 234.50it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.288, Accuracy 53.4): 100%|██████████| 665/665 [00:07<00:00, 89.85it/s]
# test_batch (Avg. Loss 1.232, Accuracy 55.8): 100%|██████████| 469/469 [00:02<00:00, 221.35it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.129, Accuracy 59.3): 100%|██████████| 665/665 [00:07<00:00, 88.76it/s]
# test_batch (Avg. Loss 1.139, Accuracy 59.5): 100%|██████████| 469/469 [00:02<00:00, 210.83it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.006, Accuracy 63.7): 100%|██████████| 665/665 [00:07<00:00, 88.40it/s]
# test_batch (Avg. Loss 0.979, Accuracy 65.6): 100%|██████████| 469/469 [00:02<00:00, 223.42it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 0.920, Accuracy 67.4): 100%|██████████| 665/665 [00:07<00:00, 88.36it/s]
# test_batch (Avg. Loss 0.865, Accuracy 68.4): 100%|██████████| 469/469 [00:02<00:00, 219.79it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.856, Accuracy 69.6): 100%|██████████| 665/665 [00:07<00:00, 88.84it/s]
# test_batch (Avg. Loss 0.835, Accuracy 70.5): 100%|██████████| 469/469 [00:02<00:00, 224.12it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.812, Accuracy 71.2): 100%|██████████| 665/665 [00:07<00:00, 90.32it/s]
# test_batch (Avg. Loss 0.787, Accuracy 72.4): 100%|██████████| 469/469 [00:02<00:00, 210.18it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.768, Accuracy 72.8): 100%|██████████| 665/665 [00:07<00:00, 88.88it/s]
# test_batch (Avg. Loss 0.786, Accuracy 72.3): 100%|██████████| 469/469 [00:02<00:00, 215.74it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.738, Accuracy 73.9): 100%|██████████| 665/665 [00:07<00:00, 88.49it/s]
# test_batch (Avg. Loss 0.750, Accuracy 73.8): 100%|██████████| 469/469 [00:02<00:00, 225.21it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.708, Accuracy 74.9): 100%|██████████| 665/665 [00:07<00:00, 88.68it/s]
# test_batch (Avg. Loss 0.740, Accuracy 74.0): 100%|██████████| 469/469 [00:02<00:00, 227.30it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.679, Accuracy 76.1): 100%|██████████| 665/665 [00:07<00:00, 89.39it/s]
# test_batch (Avg. Loss 0.696, Accuracy 75.4): 100%|██████████| 469/469 [00:02<00:00, 214.68it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.655, Accuracy 76.9): 100%|██████████| 665/665 [00:07<00:00, 89.76it/s]
# test_batch (Avg. Loss 0.646, Accuracy 77.3): 100%|██████████| 469/469 [00:02<00:00, 227.19it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.630, Accuracy 77.8): 100%|██████████| 665/665 [00:07<00:00, 89.23it/s]
# test_batch (Avg. Loss 0.659, Accuracy 77.0): 100%|██████████| 469/469 [00:02<00:00, 218.64it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.606, Accuracy 78.6): 100%|██████████| 665/665 [00:07<00:00, 91.49it/s]
# test_batch (Avg. Loss 0.644, Accuracy 77.6): 100%|██████████| 469/469 [00:02<00:00, 217.72it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0
/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.394, Accuracy 86.0): 100%|██████████| 665/665 [00:07<00:00, 90.13it/s]
# test_batch (Avg. Loss 0.503, Accuracy 83.0): 100%|██████████| 469/469 [00:02<00:00, 208.90it/s]
# test_batch (Avg. Loss 0.521, Accuracy 82.5): 100%|██████████| 625/625 [00:04<00:00, 137.20it/s]
# ==================== Test Results ====================
# Test Accuracy: 82.53
# Test Accuracy: 0.5205703975141048
# ======================================================
# *** Output file ./results/exp2_2_sgd_lr0.0005.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU()
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     lr: 0.1
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.298, Accuracy 11.1): 100%|██████████| 665/665 [00:07<00:00, 89.76it/s]
# test_batch (Avg. Loss 2.305, Accuracy 9.7): 100%|██████████| 469/469 [00:02<00:00, 211.48it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 9.7): 100%|██████████| 665/665 [00:07<00:00, 88.93it/s]
# test_batch (Avg. Loss 2.305, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 211.05it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 665/665 [00:07<00:00, 88.90it/s]
# test_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 219.62it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 86.03it/s]
# test_batch (Avg. Loss 2.311, Accuracy 9.6): 100%|██████████| 469/469 [00:02<00:00, 207.32it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 665/665 [00:07<00:00, 89.64it/s]
# test_batch (Avg. Loss 2.308, Accuracy 9.7): 100%|██████████| 469/469 [00:02<00:00, 211.42it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 88.98it/s]
# test_batch (Avg. Loss 2.305, Accuracy 10.4): 100%|██████████| 469/469 [00:02<00:00, 215.51it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 88.62it/s]
# test_batch (Avg. Loss 2.306, Accuracy 9.8): 100%|██████████| 469/469 [00:02<00:00, 230.35it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.2): 100%|██████████| 665/665 [00:07<00:00, 88.77it/s]
# test_batch (Avg. Loss 2.307, Accuracy 10.3): 100%|██████████| 469/469 [00:02<00:00, 218.96it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.307, Accuracy 9.9): 100%|██████████| 665/665 [00:07<00:00, 88.55it/s]
# test_batch (Avg. Loss 2.305, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 217.82it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 89.90it/s]
# test_batch (Avg. Loss 2.307, Accuracy 10.4): 100%|██████████| 469/469 [00:02<00:00, 207.16it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 2.307, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 88.06it/s]
# test_batch (Avg. Loss 2.307, Accuracy 9.7): 100%|██████████| 469/469 [00:02<00:00, 203.38it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 9.9): 100%|██████████| 665/665 [00:07<00:00, 92.83it/s]
# test_batch (Avg. Loss 2.304, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 231.70it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 9.9): 100%|██████████| 665/665 [00:07<00:00, 90.06it/s]
# test_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 229.79it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 89.93it/s]
# test_batch (Avg. Loss 2.304, Accuracy 9.8): 100%|██████████| 469/469 [00:02<00:00, 217.38it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 665/665 [00:07<00:00, 89.68it/s]
# test_batch (Avg. Loss 2.305, Accuracy 9.8): 100%|██████████| 469/469 [00:02<00:00, 192.76it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 88.49it/s]
# test_batch (Avg. Loss 2.309, Accuracy 10.4): 100%|██████████| 469/469 [00:02<00:00, 199.24it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 9.9): 100%|██████████| 665/665 [00:07<00:00, 90.45it/s]
# test_batch (Avg. Loss 2.308, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 209.45it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 665/665 [00:07<00:00, 89.36it/s]
# test_batch (Avg. Loss 2.305, Accuracy 9.9): 100%|██████████| 469/469 [00:02<00:00, 207.76it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 9.9): 100%|██████████| 665/665 [00:07<00:00, 89.16it/s]
# test_batch (Avg. Loss 2.305, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 219.49it/s]
# --- EPOCH 20/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 89.96it/s]
# test_batch (Avg. Loss 2.307, Accuracy 9.7): 100%|██████████| 469/469 [00:02<00:00, 215.93it/s]
# --- EPOCH 21/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 88.62it/s]
# test_batch (Avg. Loss 2.304, Accuracy 9.7): 100%|██████████| 469/469 [00:02<00:00, 214.52it/s]
# --- EPOCH 22/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 89.50it/s]
# test_batch (Avg. Loss 2.309, Accuracy 9.7): 100%|██████████| 469/469 [00:02<00:00, 208.10it/s]
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 665/665 [00:07<00:00, 88.36it/s]
# test_batch (Avg. Loss 2.307, Accuracy 9.7): 100%|██████████| 469/469 [00:02<00:00, 211.77it/s]
# --- EPOCH 24/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.0): 100%|██████████| 665/665 [00:07<00:00, 85.35it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 208.06it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 665/665 [00:07<00:00, 88.00it/s]
# test_batch (Avg. Loss 2.304, Accuracy 10.5): 100%|██████████| 469/469 [00:02<00:00, 219.57it/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 2.307, Accuracy 9.9): 100%|██████████| 665/665 [00:07<00:00, 89.62it/s]
# test_batch (Avg. Loss 2.306, Accuracy 9.6): 100%|██████████| 469/469 [00:02<00:00, 203.26it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.1): 100%|██████████| 665/665 [00:07<00:00, 87.63it/s]
# test_batch (Avg. Loss 2.308, Accuracy 9.9): 100%|██████████| 469/469 [00:02<00:00, 206.07it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.2): 100%|██████████| 665/665 [00:07<00:00, 87.67it/s]
# test_batch (Avg. Loss 2.304, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 207.73it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.2): 100%|██████████| 665/665 [00:07<00:00, 88.16it/s]
# test_batch (Avg. Loss 2.306, Accuracy 9.9): 100%|██████████| 469/469 [00:02<00:00, 226.13it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 2.306, Accuracy 10.2): 100%|██████████| 665/665 [00:07<00:00, 88.32it/s]
# test_batch (Avg. Loss 2.305, Accuracy 9.8): 100%|██████████| 469/469 [00:02<00:00, 204.05it/s]
# test_batch (Avg. Loss 2.305, Accuracy 10.0): 100%|██████████| 625/625 [00:04<00:00, 129.37it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3046606971740724
# ======================================================
# *** Output file ./results/exp2_2_sgd_lr0.1.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU()
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1
/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.162, Accuracy 94.2): 100%|██████████| 665/665 [00:07<00:00, 87.42it/s]
# test_batch (Avg. Loss 0.567, Accuracy 84.3): 100%|██████████| 469/469 [00:02<00:00, 216.55it/s]
# test_batch (Avg. Loss 0.595, Accuracy 84.3): 100%|██████████| 625/625 [00:04<00:00, 133.33it/s]
# ==================== Test Results ====================
# Test Accuracy: 84.34
# Test Accuracy: 0.5946794985964894
# ======================================================
# *** Output file ./results/exp2_2_sgd_lr0.01.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU()
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# optimizer : Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0.002
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.305, Accuracy 52.8): 100%|██████████| 665/665 [00:08<00:00, 82.13it/s]
# test_batch (Avg. Loss 0.980, Accuracy 64.5): 100%|██████████| 469/469 [00:02<00:00, 202.84it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 0.887, Accuracy 68.5): 100%|██████████| 665/665 [00:08<00:00, 80.59it/s]
# test_batch (Avg. Loss 0.816, Accuracy 71.0): 100%|██████████| 469/469 [00:02<00:00, 196.05it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 0.739, Accuracy 73.8): 100%|██████████| 665/665 [00:08<00:00, 80.91it/s]
# test_batch (Avg. Loss 0.691, Accuracy 76.0): 100%|██████████| 469/469 [00:02<00:00, 206.80it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 0.655, Accuracy 77.2): 100%|██████████| 665/665 [00:08<00:00, 79.76it/s]
# test_batch (Avg. Loss 0.639, Accuracy 77.7): 100%|██████████| 469/469 [00:02<00:00, 209.70it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 0.584, Accuracy 79.5): 100%|██████████| 665/665 [00:08<00:00, 80.55it/s]
# test_batch (Avg. Loss 0.594, Accuracy 79.6): 100%|██████████| 469/469 [00:02<00:00, 197.33it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.545, Accuracy 80.8): 100%|██████████| 665/665 [00:08<00:00, 80.12it/s]
# test_batch (Avg. Loss 0.600, Accuracy 79.6): 100%|██████████| 469/469 [00:02<00:00, 200.22it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.515, Accuracy 81.9): 100%|██████████| 665/665 [00:08<00:00, 80.37it/s]
# test_batch (Avg. Loss 0.526, Accuracy 81.8): 100%|██████████| 469/469 [00:02<00:00, 191.22it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.484, Accuracy 83.1): 100%|██████████| 665/665 [00:08<00:00, 78.98it/s]
# test_batch (Avg. Loss 0.622, Accuracy 79.0): 100%|██████████| 469/469 [00:02<00:00, 200.80it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.456, Accuracy 83.9): 100%|██████████| 665/665 [00:08<00:00, 80.10it/s]
# test_batch (Avg. Loss 0.544, Accuracy 81.7): 100%|██████████| 469/469 [00:02<00:00, 204.67it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.438, Accuracy 84.6): 100%|██████████| 665/665 [00:08<00:00, 82.02it/s]
# test_batch (Avg. Loss 0.554, Accuracy 81.7): 100%|██████████| 469/469 [00:02<00:00, 201.83it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.423, Accuracy 85.3): 100%|██████████| 665/665 [00:08<00:00, 80.52it/s]
# test_batch (Avg. Loss 0.474, Accuracy 83.5): 100%|██████████| 469/469 [00:02<00:00, 205.83it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.408, Accuracy 85.7): 100%|██████████| 665/665 [00:08<00:00, 80.22it/s]
# test_batch (Avg. Loss 0.501, Accuracy 82.9): 100%|██████████| 469/469 [00:02<00:00, 203.45it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.403, Accuracy 86.0): 100%|██████████| 665/665 [00:08<00:00, 79.88it/s]
# test_batch (Avg. Loss 0.481, Accuracy 83.2): 100%|██████████| 469/469 [00:02<00:00, 200.16it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0
/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.316, Accuracy 89.0): 100%|██████████| 665/665 [00:08<00:00, 78.61it/s]
# test_batch (Avg. Loss 0.445, Accuracy 85.0): 100%|██████████| 469/469 [00:02<00:00, 209.26it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.304, Accuracy 89.3): 100%|██████████| 665/665 [00:08<00:00, 78.54it/s]
# test_batch (Avg. Loss 0.428, Accuracy 85.4): 100%|██████████| 469/469 [00:02<00:00, 216.21it/s]
# test_batch (Avg. Loss 0.443, Accuracy 85.2): 100%|██████████| 625/625 [00:04<00:00, 131.82it/s]
# ==================== Test Results ====================
# Test Accuracy: 85.25
# Test Accuracy: 0.4431232611373067
# ======================================================
# *** Output file ./results/exp2_2_adam_lr0.0005.json written
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU()
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# optimizer : Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.1
#     maximize: False
#     weight_decay: 0.002
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 4.099, Accuracy 13.4): 100%|██████████| 665/665 [00:08<00:00, 80.23it/s]
# test_batch (Avg. Loss 2.573, Accuracy 17.0): 100%|██████████| 469/469 [00:02<00:00, 210.28it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.488, Accuracy 21.2): 100%|██████████| 665/665 [00:08<00:00, 78.15it/s]
# test_batch (Avg. Loss 2.789, Accuracy 9.6): 100%|██████████| 469/469 [00:02<00:00, 205.82it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 7.787, Accuracy 10.0): 100%|██████████| 665/665 [00:08<00:00, 78.79it/s]
# test_batch (Avg. Loss 2.309, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 215.06it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.587, Accuracy 9.8): 100%|██████████| 665/665 [00:08<00:00, 80.05it/s]
# test_batch (Avg. Loss 2.309, Accuracy 9.6): 100%|██████████| 469/469 [00:02<00:00, 209.82it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.360, Accuracy 10.1): 100%|██████████| 665/665 [00:08<00:00, 78.09it/s]
# test_batch (Avg. Loss 2.308, Accuracy 10.1): 100%|██████████| 469/469 [00:02<00:00, 214.23it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.326, Accuracy 10.4): 100%|██████████| 665/665 [00:08<00:00, 79.36it/s]
# test_batch (Avg. Loss 2.308, Accuracy 10.4): 100%|██████████| 469/469 [00:02<00:00, 211.14it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.575, Accuracy 10.4): 100%|██████████| 665/665 [00:08<00:00, 78.78it/s]
# test_batch (Avg. Loss 1255706.859, Accuracy 9.8): 100%|██████████| 469/469 [00:02<00:00, 213.29it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 7.066, Accuracy 10.0): 100%|██████████| 665/665 [00:08<00:00, 79.54it/s]
# test_batch (Avg. Loss 2.309, Accuracy 10.3): 100%|██████████| 469/469 [00:02<00:00, 213.83it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.640, Accuracy 9.9): 100%|██████████| 665/665 [00:08<00:00, 80.26it/s]
# test_batch (Avg. Loss 2.307, Accuracy 10.4): 100%|██████████| 469/469 [00:02<00:00, 215.55it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 3.349, Accuracy 10.0): 100%|██████████| 665/665 [00:08<00:00, 79.29it/s]
# test_batch (Avg. Loss 872.442, Accuracy 9.0): 100%|██████████| 469/469 [00:02<00:00, 217.85it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 5.074, Accuracy 10.0): 100%|██████████| 665/665 [00:08<00:00, 79.09it/s]
# test_batch (Avg. Loss 2.305, Accuracy 9.7): 100%|██████████| 469/469 [00:02<00:00, 206.08it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss
/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 1.123, Accuracy 60.2): 100%|██████████| 665/665 [00:08<00:00, 77.26it/s]
# test_batch (Avg. Loss 1.375, Accuracy 53.7): 100%|██████████| 469/469 [00:02<00:00, 211.57it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 1.124, Accuracy 60.3): 100%|██████████| 665/665 [00:08<00:00, 76.14it/s]
# test_batch (Avg. Loss 1.230, Accuracy 58.0): 100%|██████████| 469/469 [00:02<00:00, 220.76it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 1.125, Accuracy 60.4): 100%|██████████| 665/665 [00:08<00:00, 79.32it/s]
# test_batch (Avg. Loss 1.356, Accuracy 53.5): 100%|██████████| 469/469 [00:02<00:00, 221.64it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 1.132, Accuracy 60.4): 100%|██████████| 665/665 [00:08<00:00, 77.16it/s]
# test_batch (Avg. Loss 1.129, Accuracy 59.3): 100%|██████████| 469/469 [00:02<00:00, 206.55it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 1.121, Accuracy 60.5): 100%|██████████| 665/665 [00:08<00:00, 77.51it/s]
# test_batch (Avg. Loss 1.434, Accuracy 48.8): 100%|██████████| 469/469 [00:02<00:00, 226.01it/s]
# test_batch (Avg. Loss 1.450, Accuracy 48.5): 100%|██████████| 625/625 [00:04<00:00, 141.27it/s]
# ==================== Test Results ====================
# Test Accuracy: 48.45
# Test Accuracy: 1.4501612062454223
# ======================================================
# *** Output file ./results/exp2_2_adam_lr0.01.json written

# %%
plot_exp_results('exp2_2*') # plot your experiments results
# Out:
# common config:  {'run_name': 'exp2_2_sgd_lr0.1', 'out_dir': './results', 'seed': 42, 'bs_train': 64, 'bs_test': 16, 'batches': 200, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.1, 'reg': 0.002, 'pool_every': 2, 'hidden_dims': [128], 'ycn': True, 'sgd': True, 'kw': {}}

# %% [markdown]
# **Answer in your Report:** Why should we add the momentum to SGD? What is the main two improvments adam has comparing to the simple SGD? What was the best optimization algorithm and best learning rate you've found?
#
# Summarize this section results in your report.
#
# **Note** - you will need to change the optimization used in experiments.run_experiment(...).

# %% [markdown]
# ### 3. Add Batch Normalization
# Add batch normalization to your network. You may want to read this blog before:
# https://www.baeldung.com/cs/batch-normalization-cnn

# %%
# set ycn=True when you call experiments.run_experiment(...)
# Use meaningful names!
# ====== YOUR CODE: ======
experiments.run_experiment(f'exp3_1_BN',
  seed=seed,
  bs_train=64,
  batches=200,
  epochs=30, 
  early_stopping=5,
  reg=2e-3,
  lr=1e-3,
  filters_per_layer=[32,64,128],
  layers_per_block=2,
  pool_every=2, 
  ycn=True, 
  hidden_dims=[128])
# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.30000000000000004, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU()
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (23): Dropout(p=0.4, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# optimizer : Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0.002
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.262, Accuracy 54.3): 100%|██████████| 665/665 [00:07<00:00, 83.82it/s]
# test_batch (Avg. Loss 0.966, Accuracy 64.9): 100%|██████████| 469/469 [00:02<00:00, 219.62it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 0.853, Accuracy 70.0): 100%|██████████| 665/665 [00:07<00:00, 84.96it/s]
# test_batch (Avg. Loss 0.826, Accuracy 70.7): 100%|██████████| 469/469 [00:02<00:00, 223.88it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss
/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.480, Accuracy 83.4): 100%|██████████| 665/665 [00:08<00:00, 80.37it/s]
# test_batch (Avg. Loss 0.495, Accuracy 83.4): 100%|██████████| 469/469 [00:02<00:00, 206.50it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.486, Accuracy 83.2): 100%|██████████| 665/665 [00:08<00:00, 79.32it/s]
# test_batch (Avg. Loss 0.530, Accuracy 81.7): 100%|██████████| 469/469 [00:02<00:00, 213.38it/s]
# --- EPOCH 20/30 ---
# train_batch (Avg. Loss 0.476, Accuracy 83.4): 100%|██████████| 665/665 [00:08<00:00, 80.79it/s]
# test_batch (Avg. Loss 0.518, Accuracy 82.5): 100%|██████████| 469/469 [00:02<00:00, 208.90it/s]
# --- EPOCH 21/30 ---
# train_batch (Avg. Loss 0.470, Accuracy 83.6): 100%|██████████| 665/665 [00:08<00:00, 79.59it/s]
# test_batch (Avg. Loss 0.543, Accuracy 81.2): 100%|██████████| 469/469 [00:02<00:00, 214.43it/s]
# --- EPOCH 22/30 ---
# train_batch (Avg. Loss 0.465, Accuracy 83.8): 100%|██████████| 665/665 [00:07<00:00, 83.96it/s]
# test_batch (Avg. Loss 0.523, Accuracy 81.9): 100%|██████████| 469/469 [00:02<00:00, 208.29it/s]
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 0.467, Accuracy 83.7): 100%|██████████| 665/665 [00:07<00:00, 83.90it/s]
# test_batch (Avg. Loss 0.547, Accuracy 81.7): 100%|██████████| 469/469 [00:02<00:00, 203.40it/s]
# --- EPOCH 24/30 ---
# train_batch (Avg. Loss 0.465, Accuracy 83.9): 100%|██████████| 665/665 [00:08<00:00, 79.75it/s]
# test_batch (Avg. Loss 0.496, Accuracy 83.1): 100%|██████████| 469/469 [00:02<00:00, 202.97it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.461, Accuracy 84.0): 100%|██████████| 665/665 [00:08<00:00, 82.52it/s]
# test_batch (Avg. Loss 0.502, Accuracy 83.2): 100%|██████████| 469/469 [00:02<00:00, 210.89it/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 0.461, Accuracy 84.0): 100%|██████████| 665/665 [00:08<00:00, 81.35it/s]
# test_batch (Avg. Loss 0.479, Accuracy 83.4): 100%|██████████| 469/469 [00:02<00:00, 216.43it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 0.461, Accuracy 84.2): 100%|██████████| 665/665 [00:08<00:00, 79.50it/s]
# test_batch (Avg. Loss 0.472, Accuracy 83.7): 100%|██████████| 469/469 [00:02<00:00, 198.80it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 0.455, Accuracy 84.2): 100%|██████████| 665/665 [00:08<00:00, 77.75it/s]
# test_batch (Avg. Loss 0.498, Accuracy 83.1): 100%|██████████| 469/469 [00:02<00:00, 214.33it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.463, Accuracy 83.9): 100%|██████████| 665/665 [00:08<00:00, 80.07it/s]
# test_batch (Avg. Loss 0.518, Accuracy 82.2): 100%|██████████| 469/469 [00:02<00:00, 203.47it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.448, Accuracy 84.6): 100%|██████████| 665/665 [00:07<00:00, 83.56it/s]
# test_batch (Avg. Loss 0.537, Accuracy 81.9): 100%|██████████| 469/469 [00:02<00:00, 222.24it/s]
# test_batch (Avg. Loss 0.554, Accuracy 82.0): 100%|██████████| 625/625 [00:04<00:00, 139.46it/s]
# ==================== Test Results ====================
# Test Accuracy: 81.98
# Test Accuracy: 0.5539410288631916
# ======================================================
# *** Output file ./results/exp3_1_BN.json written

# %%
plot_exp_results('exp3*') # plot your experiments results
# Out:
# common config:  {'run_name': 'exp3_1_BN', 'out_dir': './results', 'seed': 42, 'bs_train': 64, 'bs_test': 16, 'batches': 200, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 2, 'hidden_dims': [128], 'ycn': True, 'sgd': False, 'kw': {}}

# %% [markdown]
# **Answer in your Report:** What is the purpose of batch normalization (why do we use it)?
# Did the Batch normalization improve the network preformance?
# Summeraize this section results in your report.

# %% [markdown]
# ### 4. Regularization
# Try to add regularization to your optimization. In particular add L2 regularization (read about weight_decay in adam) and dropout layer to your network (try them separately).

# %%
# set ycn=True when you call experiments.run_experiment(...)
# Use meaningful names!
# ====== YOUR CODE: ======
for reg, dropouts in [(0, True), (2e-3, False)]:
  regType = 'Dropouts' if dropouts else 'L2'
  experiments.run_experiment(f'exp4_1_REG_{regType}',
    seed=seed,
    bs_train=64,
    batches=200,
    epochs=30, 
    early_stopping=5,
    reg=reg,
    dropouts=dropouts,
    lr=1e-3,
    filters_per_layer=[32,64,128],
    layers_per_block=2,
    pool_every=2, 
    ycn=True, 
    hidden_dims=[128])
# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# YourCodeNet(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU()
#     (16): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU()
#     (19): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# optimizer : Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0.002
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.140, Accuracy 59.1): 100%|██████████| 665/665 [00:07<00:00, 88.97it/s]
# test_batch (Avg. Loss 0.939, Accuracy 66.6): 100%|██████████| 469/469 [00:01<00:00, 237.35it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 0.723, Accuracy 74.4): 100%|██████████| 665/665 [00:07<00:00, 88.85it/s]
# test_batch (Avg. Loss 0.829, Accuracy 71.3): 100%|██████████| 469/469 [00:01<00:00, 235.38it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 0.595, Accuracy 79.3): 100%|██████████| 665/665 [00:07<00:00, 87.32it/s]
# test_batch (Avg. Loss 0.637, Accuracy 78.1): 100%|██████████| 469/469 [00:02<00:00, 220.24it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 0.518, Accuracy 82.0): 100%|██████████| 665/665 [00:07<00:00, 86.75it/s]
# test_batch (Avg. Loss 0.613, Accuracy 78.7): 100%|██████████| 469/469 [00:02<00:00, 232.68it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 0.460, Accuracy 84.0): 100%|██████████| 665/665 [00:07<00:00, 82.22it/s]
# test_batch (Avg. Loss 0.622, Accuracy 78.8): 100%|██████████| 469/469 [00:02<00:00, 227.38it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.423, Accuracy 85.3): 100%|██████████| 665/665 [00:07<00:00, 87.94it/s]
# test_batch (Avg. Loss 0.639, Accuracy 78.5): 100%|██████████| 469/469 [00:02<00:00, 231.31it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.397, Accuracy 86.4): 100%|██████████| 665/665 [00:07<00:00, 86.28it/s]
# test_batch (Avg. Loss 0.565, Accuracy 81.2): 100%|██████████| 469/469 [00:02<00:00, 229.19it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.370, Accuracy 87.1): 100%|██████████| 665/665 [00:08<00:00, 85.14it/s]
# test_batch (Avg. Loss 0.573, Accuracy 80.8): 100%|██████████| 469/469 [00:02<00:00, 222.85it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.353, Accuracy 87.7): 100%|██████████| 665/665 [00:07<00:00, 87.29it/s]
# test_batch (Avg. Loss 0.562, Accuracy 81.5): 100%|██████████| 469/469 [00:02<00:00, 232.97it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.328, Accuracy 88.7): 100%|██████████| 665/665 [00:07<00:00, 87.22it/s]
# test_batch (Avg. Loss 0.573, Accuracy 80.8): 100%|██████████| 469/469 [00:01<00:00, 238.99it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0
/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 0.221, Accuracy 92.3): 100%|██████████| 665/665 [00:07<00:00, 86.99it/s]
# test_batch (Avg. Loss 0.617, Accuracy 80.7): 100%|██████████| 469/469 [00:01<00:00, 234.92it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 0.226, Accuracy 92.0): 100%|██████████| 665/665 [00:07<00:00, 85.04it/s]
# test_batch (Avg. Loss 0.581, Accuracy 81.5): 100%|██████████| 469/469 [00:02<00:00, 194.27it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.243, Accuracy 91.7): 100%|██████████| 665/665 [00:08<00:00, 82.13it/s]
# test_batch (Avg. Loss 0.629, Accuracy 80.7): 100%|██████████| 469/469 [00:01<00:00, 242.20it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.206, Accuracy 92.9): 100%|██████████| 665/665 [00:07<00:00, 86.50it/s]
# test_batch (Avg. Loss 0.563, Accuracy 83.0): 100%|██████████| 469/469 [00:02<00:00, 229.87it/s]
# test_batch (Avg. Loss 0.566, Accuracy 83.3): 100%|██████████| 625/625 [00:04<00:00, 146.73it/s]
# ==================== Test Results ====================
# Test Accuracy: 83.28
# Test Accuracy: 0.5658048367589712
# ======================================================
# *** Output file ./results/exp4_1_REG_L2.json written

# %%
plot_exp_results('exp4*') # plot your experiments results
# Out:
# common config:  {'run_name': 'exp4_1_REG_L2', 'out_dir': './results', 'seed': 42, 'bs_train': 64, 'bs_test': 16, 'batches': 200, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 2, 'hidden_dims': [128], 'ycn': True, 'sgd': False, 'dropouts': False, 'kw': {}}

# %% [markdown]
# **Answer in your Report:** Why should we use regularization?
# How does the regularization affect the train accuracy and loss? How does it affect the val and test accuracy and loss? What was the best regulrization method?
# Summarize this section results in your report.

# %% [markdown]
# ## Summary Up To Here
# **Answer in your Report:** What is your best architecture? what its best accuracy and loss on the test set? Compare your result to assignment 2. How did you mange to improve the model? Summarize this section results in your report.

# %% [markdown]
# ## Use predefined network
# You may want to read about ResNet in this blog:
#
# https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035

# %% [markdown]
# ### 5. Pretrained ResNet50

# %% [markdown]
# Now use ResNet50 with pretraining (use pretrained=True when you load the model) and run this model on cifar 10.
# you will need to change the last linear layer. Tip: `model.fc = nn.Linear(2048, 10)`. you may want to use lower learning rate.

# %%
# Use meaningful names!
# ====== YOUR CODE: ======
# net = models.resnet50(pretrained=True).to(device) 

# for param in net.parameters():
#     param.requires_grad = False
    
# net.fc = nn.Sequential(
#                nn.Linear(2048, 10)).to(device)

experiments.run_experiment(f'exp5_3_resnet_50',
    seed=seed,
    bs_train=64,
    batches=200,
    epochs=30,
    early_stopping=5,
    lr=1e-5,
    filters_per_layer=[32,64,128],
    layers_per_block=2,
    pool_every=2, 
    ycn=True, 
    resnet=True,
    hidden_dims=[128])

# ========================
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Layer "layer4" was unfrozen!
# Layer "layer4" was unfrozen!
# Layer "layer4" was unfrozen!
# optimizer : Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.001
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.230, Accuracy 56.9): 100%|██████████| 665/665 [11:42<00:00,  1.27it/s]
# test_batch (Avg. Loss 0.935, Accuracy 67.0): 100%|██████████| 469/469 [01:05<00:00,  7.43it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 0.792, Accuracy 72.4): 100%|██████████| 665/665 [11:52<00:00,  1.01s/it]
# test_batch (Avg. Loss 0.865, Accuracy 69.4): 100%|██████████| 469/469 [01:04<00:00,  7.61it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 0.576, Accuracy 80.1): 100%|██████████| 665/665 [15:25<00:00,  1.19s/it]
# test_batch (Avg. Loss 0.893, Accuracy 70.2): 100%|██████████| 469/469 [01:07<00:00,  7.34it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 0.429, Accuracy 85.4): 100%|██████████| 665/665 [15:29<00:00,  1.13s/it]
# test_batch (Avg. Loss 0.955, Accuracy 70.1): 100%|██████████| 469/469 [01:05<00:00,  7.19it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 0.330, Accuracy 88.6): 100%|██████████| 665/665 [15:33<00:00,  1.16s/it]
# test_batch (Avg. Loss 1.016, Accuracy 70.5): 100%|██████████| 469/469 [01:06<00:00,  7.38it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.255, Accuracy 91.4): 100%|██████████| 665/665 [15:06<00:00,  1.12s/it]
# test_batch (Avg. Loss 1.038, Accuracy 70.3): 100%|██████████| 469/469 [01:05<00:00,  7.61it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.214, Accuracy 92.8): 100%|██████████| 665/665 [15:11<00:00,  1.13s/it]
# test_batch (Avg. Loss 1.095, Accuracy 70.6): 100%|██████████| 469/469 [01:06<00:00,  7.24it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.190, Accuracy 93.4): 100%|██████████| 665/665 [15:27<00:00,  1.17s/it]
# test_batch (Avg. Loss 1.125, Accuracy 69.8): 100%|██████████| 469/469 [01:06<00:00,  7.44it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.173, Accuracy 94.3): 100%|██████████| 665/665 [15:26<00:00,  1.17s/it]
# test_batch (Avg. Loss 1.168, Accuracy 70.6): 100%|██████████| 469/469 [01:07<00:00,  7.46it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.156, Accuracy 94.8): 100%|██████████| 665/665 [15:16<00:00,  1.18s/it]
# test_batch (Avg. Loss 1.149, Accuracy 70.6): 100%|██████████| 469/469 [01:08<00:00,  7.28it/s]
# --- EPOCH 11/30 ---
# train_batch (0.115):  70%|███████   | 468/665 [10:55<04:30,  1.37s/it]

# %%
plot_exp_results('exp5_2*') # plot your experiments results
# Out:
# common config:  {'run_name': 'exp5_2_resnet_50', 'out_dir': './results', 'seed': 42, 'bs_train': 64, 'bs_test': 16, 'batches': 200, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 1e-05, 'reg': 0.001, 'pool_every': 2, 'hidden_dims': [128], 'ycn': True, 'sgd': False, 'dropouts': True, 'resnet': True, 'kw': {}}

# %% [markdown]
# **Answer in your Report:** What was the pretrained ResNet50 accuracy and loss? Is it overfit/underfit/well-fit the data? Has it got better accuracy than the non-pretrained ResNet? Summarize this section results in your report.

# %% [markdown]
# ### 5. Summeraize Bert and ViT blogs
# Read these two blogs:
# 1. https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270
# 2. https://towardsdatascience.com/what-are-vision-transformers-and-how-are-they-important-for-general-purpose-learning-edd008545e9e
#
# Summeraize the bert and ViT information from these two blogs in hebrew.

# %% [markdown]
# ## Project Summary
# **Answer in your Report:** Write a short summerization of your attempts. What worked for you? which architecture and hyperparameters led to the best preformance?
